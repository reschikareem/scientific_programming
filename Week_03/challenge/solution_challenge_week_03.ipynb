# %% [markdown]
# # Getting all available Swiss petrol stations using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import json
import folium
import requests
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# u:\Lektionen\GitHub_Repositories\scientific_programming\Week_03\challenge

# %% [markdown]
# ## Overpass turbo query to get available petrol stations

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["amenity"="fuel"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to .json file
with open('petrol_stations.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = pd.json_normalize(data)
df.head()
# Out:
#    type        id        lat       lon tags.amenity tags.brand  \
# 0  node   1228781  46.878598  7.542326         fuel         BP
# 1  node   5702030  46.680546  7.827412         fuel     Migrol
# 2  node   5702071  46.683415  7.844559         fuel       Avia
# 3  node   8082505  46.683817  7.664427         fuel        NaN
# 4  node  17407058  47.054727  7.625379         fuel        NaN
#
#   tags.fuel:diesel tags.operator tags.wheelchair tags.brand:wikidata  ...  \
# 0              yes            BP             yes                 NaN  ...
# 1              NaN           NaN             NaN            Q1747771  ...
# 2              yes          Avia             NaN             Q300147  ...
# 3              NaN           NaN         limited                 NaN  ...
# 4              NaN         Shell             NaN                 NaN  ...
#
#   tags.payment:ec_cards tags.fuel:lng tags.fuel:petrol tags.outdoor_seating  \
# 0                   NaN           NaN              NaN                  NaN
# 1                   NaN           NaN              NaN                  NaN
# 2                   NaN           NaN              NaN                  NaN
# 3                   NaN           NaN              NaN                  NaN
# 4                   NaN           NaN              NaN                  NaN
#
#   tags.operator:wikidata tags.maxheight:signed tags.currency:others  \
# 0                    NaN                   NaN                  NaN
# 1                    NaN                   NaN                  NaN
# 2                    NaN                   NaN                  NaN
# 3                    NaN                   NaN                  NaN
# 4                    NaN                   NaN                  NaN
#
#   tags.payment:euroshell tags.fuel:h35 tags.fuel:h70
# 0                    NaN           NaN           NaN
# 1                    NaN           NaN           NaN
# 2                    NaN           NaN           NaN
# 3                    NaN           NaN           NaN
# 4                    NaN           NaN           NaN
#
# [5 rows x 201 columns]

# %% [markdown]
# ## Save data frame to a .csv file

# %%
# Write data frame to .csv - file
df.to_csv('petrol-stations.csv', index=False, sep=";", encoding='utf-8')

# %% [markdown]
# ## Use a pivot table to count the number of petrol stations per operator

# %%
# Create pivot table
tab = pd.pivot_table(df[['id', 'tags.name']], 
                       values=['id'], 
                       index=['tags.name'],
                       aggfunc='count')

# Sort pivot table
tab_sorted = tab.sort_values(by=['id'], ascending=False)
tab_sorted
# Out:
#                          id
# tags.name
# Avia                    172
# Agrola                  161
# BP                      115
# Tamoil                  103
# Shell                    78
# ...                     ...
# Garage du Clos            1
# Garage du Crêt            1
# Garage du Gros-de-Vaud    1
# Garage du Nord            1
# volg                      1
#
# [817 rows x 1 columns]

# %% [markdown]
# ## Plot petrol stations on map

# %%
# Subset of petrol stations by brand
locations = df[["lat", 
                "lon", 
                "tags.brand", 
                "tags.shop"]].loc[df["tags.brand"].isin(['Migrol', 
                                                         'Agip', 
                                                         'Shell'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand tags.shop
# 1   46.680546  7.827412     Migrol       NaN
# 7   47.686119  8.621418      Shell       NaN
# 18  47.495696  8.712981      Shell       NaN
# 22  47.381593  8.509545      Shell       NaN
# 27  47.381110  8.492148     Migrol       NaN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eef86a4a15ca567918eb6f56a073e9fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eef86a4a15ca567918eb6f56a073e9fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eef86a4a15ca567918eb6f56a073e9fb = L.map(
#                 &quot;map_eef86a4a15ca567918eb6f56a073e9fb&quot;,
#                 {
#                     center: [47.08554527721894, 8.145988408579882],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_eef86a4a15ca567918eb6f56a073e9fb);
#
#
#
#
#
#             var tile_layer_0bd7655aba9cfc56f4b42d8a16f46859 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0bd7655aba9cfc56f4b42d8a16f46859.addTo(map_eef86a4a15ca567918eb6f56a073e9fb);
#
#
#             var marker_072b9909abe9e8e981abb5388045198b = L.marker(
#                 [46.6805465, 7.8274119],
#                 {}
#             ).addTo(map_eef86a4a15ca567918eb6f56a073e9fb);
#
#
#         var popup_8145e63741881c6aecbc1f17c5536094 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4192b617335c3f031e28208cd8b846d9 = $(`&lt;div id=&quot;html_4192b617335c3f031e28208cd8b846d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migrol&lt;/div&gt;`)[0];
#                 popup_8145e63741881c6aecbc1f17c5536094.setContent(html_4192b617335c3f031e28208cd8b846d9);
#
#
#
#         marker_072b9909abe9e8e981abb5388045198b.bindPopup(popup_8145e63741881c6aecbc1f17c5536094)
#         ;
#
#
#
#
#             var marker_55862836d114707c8af63a45d10f9d8c = L.marker(
#                 [47.686119, 8.621418],
#                 {}
#             ).addTo(map_eef86a4a15ca567918eb6f56a073e9fb);
#
#
#         var popup_5f6b1075f51d4d3859e5d5cb4bc80824 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6881c9ce6f0a199ae2485c8e31a46243 = $(`&lt;div id=&quot;html_6881c9ce6f0a199ae2485c8e31a46243&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_5f6b1075f51d4d3859e5d5cb4bc80824.setContent(html_6881c9ce6f0a199ae2485c8e31a46243);
#
#
#
#         marker_55862836d114707c8af63a45d10f9d8c.bindPopup(popup_5f6b1075f51d4d3859e5d5cb4bc80824)
#         ;
#
#
#
#
#             var marker_ca23eef62551b0d94eb214dbd13c4f97 = L.marker(
#                 [47.4956958, 8.7129812],
#                 {}
#             ).addTo(map_eef86a4a15ca567918eb6f56a073e9fb);
#
#
#         var popup_afd36dde4454e299ad238ab231b2fe24 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b497bb0d05fdac9cb52d924568879bb1 = $(`&lt;div id=&quot;html_b497bb0d05fdac9cb52d924568879bb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_afd36dde4454e299ad238ab231b2fe24.setContent(html_b497bb0d05fdac9cb52d924568879bb1);
#
#
#
#         marker_ca23eef62551b0d94eb214dbd13c4f97.bindPopup(popup_afd36dde4454e299ad238ab231b2fe24)
#         ;
#
#
#
#
#             var marker_8f234a9b7fcae36eb5bd171a29bc6a30 = L.marker(
#                 [47.3815928, 8.5095448],
#                 {}
#             ).addTo(map_eef86a4a15ca567918eb6f56a073e9fb);
#
#
#         var popup_0614a83d1cdf08012bb580c18111c1b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5dda378f685cba1885f472811d1c687 = $(`&lt;div id=&quot;html_b5dda378f685cba1885f472811d1c687&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_0614a83d1cdf08012bb580c18111c1b3.setContent(html_b5dda378f685cba1885f472811d1c687);
#
#
#
#         marker_8f234a9b7fcae36eb5bd171a29bc6a30.bindPopup(popup_0614a83d1cdf08012bb580c18111c1b3)
#         ;
#
#
#
#
#             var marker_2f3d0433e4ceec3b9bf39f420032c70e = L.marker(
#                 [47.3811098, 8.4921479],
#                 {}
#             ).addTo(map_eef86a4a15ca567918eb6f56a073e9fb);
#
#
#         var popup_3e5b20ae756df4803b6c9fefcbdd8493 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3acc9c73a8297adeb45a08b201f1ae0 = $(`&lt;div id=&quot;html_f3acc9c73a8297adeb45a08b201f1ae0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migrol&lt;/div&gt;`)[0];
#                 popup_3e5b20ae756df4803b6c9fefcbdd8493.setContent(html_f3acc9c73a8297adeb45a08b201f1ae0);
#
#
#
#         marker_2f3d0433e4ceec3b9bf39f420032c70e.bindPopup(popup_3e5b20ae756df4803b6c9fefcbdd8493)
#         ;
#
#
#
#
#             var marker_5ec936d6b48243bb21e888ea96fd7d9d = L.marker(
#                 [47.3374315, 8.5302419],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2025-03-12 08:22:53
# Python Version: 3.11.10
# -----------------------------------
